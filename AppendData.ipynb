# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#crimerecord_2021="Resources/COBRA-2021.CSV"
crimerecord_2020="Resources/COBRA-2020_new.CSV"
crimerecord_2009_2019="Resources/COBRA-2009-2019.csv"
#crimerecord_202009="Resources/COBRA-2020-old.CSV"

# %%
#crimerecord_2021_df=pd.read_csv(crimerecord_2021,encoding="utf-8")
#crimerecord_202009_df=pd.read_csv(crimerecord_202009,encoding="utf-8")
crimerecord_2020_df=pd.read_csv(crimerecord_2020)
crimerecord_2009_2019_df=pd.read_csv(crimerecord_2009_2019,encoding="utf-8")
# Out:
# C:\Users\gsun\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
crimerecord_2020_df = crimerecord_2020_df.dropna(how='all')

# %%
crimerecord_2020_df
# Out:
#         offense_id    rpt_date  occur_date occur_time   poss_date poss_time  \
# 0      203660108.0  12/31/2020  12/31/2020       1:15  12/31/2020      1:15
# 1      203660240.0  12/31/2020  12/31/2020       0:00  12/31/2020      5:43
# 2      203660279.0  12/31/2020  12/31/2020       3:50  12/31/2020      4:09
# 3      203660299.0  12/31/2020  12/31/2020       4:15  12/31/2020      5:52
# 4      203660335.0  12/31/2020  12/31/2020       3:00  12/31/2020      7:22
# ...            ...         ...         ...        ...         ...       ...
# 22041          NaN         NaN         NaN        NaN         NaN       NaN
# 22042          NaN         NaN         NaN        NaN         NaN       NaN
# 22043          NaN         NaN         NaN        NaN         NaN       NaN
# 22044          NaN         NaN         NaN        NaN         NaN       NaN
# 22045          NaN         NaN         NaN        NaN         NaN       NaN
#
#       beat apartment_office_prefix apartment_number  \
# ...

# %%
len(crimerecord_2020_df)
# Out:
# 22046

# %%
#crimerecordxyz = pd.to_datetime(crimerecord_2009_2019_df['Occur Date'],format='%Y-%m-%d', errors='ignore')

# %%
#crimerecordxyz
# Out:
# 0        2009-01-01
# 1        2009-01-01
# 2        2009-01-01
# 3        2009-01-01
# 4        2009-01-01
#             ...
# 342909   2019-12-31
# 342910   2019-12-31
# 342911   2019-12-31
# 342912   2019-12-31
# 342913   2019-12-31
# Name: Occur Date, Length: 342914, dtype: datetime64[ns]

# %%
#crimerecord_abc = pd.to_datetime(crimerecord_2021_df['occur_date'],format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-59-3f01fbe0d84a> in <module>
# ----> 1 crimerecord_abc = pd.to_datetime(crimerecord_2021_df['occur_date'],format='%m/%d/%Y')
#
# ...

# %%
# possible steps to rectify:
# lambda function
# filtering based on digits in year
# loop through the rows and columns

# %%
crimerecord_abc
# Out:
# 0        7/8/2020
# 1       6/13/2020
# 2       1/20/2021
# 3       10/5/2020
# 4       11/5/2020
#           ...
# 9299    1/27/2021
# 9300    1/28/2021
# 9301    1/28/2021
# 9302    1/28/2021
# 9303    1/20/2021
# Name: occur_date, Length: 9304, dtype: object

# %%
crimerecord_2020_df.columns

# %%
crimerecord_2020_df
# Out:
#         offense_id    rpt_date  occur_date occur_time   poss_date poss_time  \
# 0      203660108.0  12/31/2020  12/31/2020       1:15  12/31/2020      1:15
# 1      203660240.0  12/31/2020  12/31/2020       0:00  12/31/2020      5:43
# 2      203660279.0  12/31/2020  12/31/2020       3:50  12/31/2020      4:09
# 3      203660299.0  12/31/2020  12/31/2020       4:15  12/31/2020      5:52
# 4      203660335.0  12/31/2020  12/31/2020       3:00  12/31/2020      7:22
# ...            ...         ...         ...        ...         ...       ...
# 22041          NaN         NaN         NaN        NaN         NaN       NaN
# 22042          NaN         NaN         NaN        NaN         NaN       NaN
# 22043          NaN         NaN         NaN        NaN         NaN       NaN
# 22044          NaN         NaN         NaN        NaN         NaN       NaN
# 22045          NaN         NaN         NaN        NaN         NaN       NaN
#
#       beat apartment_office_prefix apartment_number  \
# ...

# %%
crimerecord_2009_2019_df.columns

# %%
crimerecord_2009_2019_clean=crimerecord_2009_2019_df[['Report Number', 'Occur Date', 'Occur Time', 'Location', 
       'UCR Literal','IBR Code','Neighborhood', 'Latitude','Longitude']]
crimerecord_2009_2019_clean.head()
# Out:
#    Report Number  Occur Date Occur Time                   Location  \
# 0    193651657.0  12/31/2019       1458       1388 LA FRANCE ST NE
# 1    193651031.0  12/31/2019       1300        443 MORELAND AVE SE
# 2    193650870.0  12/31/2019       1200  2711 METROPOLITAN PKWY SW
# 3    193651019.0  12/31/2019       1300         969 MARIETTA ST NW
# 4    193651039.0  12/31/2019       1300        3070 BOLLING WAY NE
#
#            UCR Literal IBR Code            Neighborhood  Latitude  Longitude
# 0  LARCENY-NON VEHICLE     2308                Edgewood  33.76053  -84.34220
# 1  LARCENY-NON VEHICLE     2302           Ormewood Park  33.74179  -84.34973
# 2  LARCENY-NON VEHICLE     2303            Hammond Park  33.68092  -84.40814
# 3  LARCENY-NON VEHICLE     2303  Marietta Street Artery  33.77828  -84.40910
# 4  LARCENY-NON VEHICLE     2303        Buckhead Village  33.83888  -84.37995

# %%
crimerecord_2020_clean=crimerecord_2020_df[['offense_id',  'occur_date', 'occur_time', 'location', 
        'UC2_Literal','ibr_code','neighborhood', 'lat', 'long']]
crimerecord_2020_clean
# Out:
#         offense_id  occur_date occur_time                     location  \
# 0      203660108.0  12/31/2020       1:15            1974 SYLVAN RD SW
# 1      203660240.0  12/31/2020       0:00             361 OLIVER ST NW
# 2      203660279.0  12/31/2020       3:50      800 WEST MARIETTA ST NW
# 3      203660299.0  12/31/2020       4:15            1054 RIDGE AVE SW
# 4      203660335.0  12/31/2020       3:00   2284 CHESHIRE BRIDGE RD NE
# ...            ...         ...        ...                          ...
# 21901  200011298.0    1/1/2020      14:45  2630 MARTIN L KING JR DR SW
# 21902  200011823.0    1/1/2020      20:00          540 HUMPHRIES ST SW
# 21903  200020105.0    1/1/2020      21:45           1174 EUCLID AVE NE
# 21904  200020704.0    1/1/2020      20:00     383 RALPH MCGILL BLVD NE
# 21905  201511120.0    1/1/2020      13:00        144 PONCE DE LEON AVE
#
#                 UC2_Literal ibr_code            neighborhood        lat  \
# ...

# %%
crime_09_19=crimerecord_2009_2019_clean.rename(columns={'Report Number':"offense_id", "Occur Date":"occur_date", "Occur Time":"occur_time", 
                                                        'Location':'location',  'UCR Literal':'UC2_Literal','IBR Code':'ibr_code','Neighborhood':'neighborhood', 'Latitude':'lat','Longitude':'long'})

crime_09_19
# Out:
#          offense_id  occur_date occur_time                   location  \
# 0       193651657.0  12/31/2019       1458       1388 LA FRANCE ST NE
# 1       193651031.0  12/31/2019       1300        443 MORELAND AVE SE
# 2       193650870.0  12/31/2019       1200  2711 METROPOLITAN PKWY SW
# 3       193651019.0  12/31/2019       1300         969 MARIETTA ST NW
# 4       193651039.0  12/31/2019       1300        3070 BOLLING WAY NE
# ...             ...         ...        ...                        ...
# 342909          NaN         NaN        NaN                        NaN
# 342910          NaN         NaN        NaN                        NaN
# 342911          NaN         NaN        NaN                        NaN
# 342912          NaN         NaN        NaN                        NaN
# 342913          NaN         NaN        NaN                        NaN
#
#                 UC2_Literal ibr_code            neighborhood       lat  \
# ...

# %%
crime_09_20=crime_09_19.append(crimerecord_2020_clean)
crime_09_20
# Out:
#         offense_id  occur_date occur_time                     location  \
# 0      193651657.0  12/31/2019       1458         1388 LA FRANCE ST NE
# 1      193651031.0  12/31/2019       1300          443 MORELAND AVE SE
# 2      193650870.0  12/31/2019       1200    2711 METROPOLITAN PKWY SW
# 3      193651019.0  12/31/2019       1300           969 MARIETTA ST NW
# 4      193651039.0  12/31/2019       1300          3070 BOLLING WAY NE
# ...            ...         ...        ...                          ...
# 21901  200011298.0    1/1/2020      14:45  2630 MARTIN L KING JR DR SW
# 21902  200011823.0    1/1/2020      20:00          540 HUMPHRIES ST SW
# 21903  200020105.0    1/1/2020      21:45           1174 EUCLID AVE NE
# 21904  200020704.0    1/1/2020      20:00     383 RALPH MCGILL BLVD NE
# 21905  201511120.0    1/1/2020      13:00        144 PONCE DE LEON AVE
#
#                UC2_Literal ibr_code            neighborhood       lat  \
# ...

# %%
crime_09_20.count()
# Out:
# offense_id      364422
# occur_date      364422
# occur_time      364422
# location        364420
# UC2_Literal     364422
# ibr_code        349562
# neighborhood    351124
# lat             364422
# long            364422
# dtype: int64

# %%
crime_09_20=crime_09_20.dropna(how='all')

# %%
crime_09_20.count()
# Out:
# offense_id      364422
# occur_date      364422
# occur_time      364422
# location        364420
# UC2_Literal     364422
# ibr_code        349562
# neighborhood    351124
# lat             364422
# long            364422
# dtype: int64

# %%
crime_09_20.dtypes
# Out:
# offense_id      float64
# occur_date       object
# occur_time       object
# location         object
# UC2_Literal      object
# ibr_code         object
# neighborhood     object
# lat             float64
# long            float64
# dtype: object

# %%
crime_09_20.head()
# Out:
#     offense_id  occur_date occur_time                   location  \
# 0  193651657.0  12/31/2019       1458       1388 LA FRANCE ST NE
# 1  193651031.0  12/31/2019       1300        443 MORELAND AVE SE
# 2  193650870.0  12/31/2019       1200  2711 METROPOLITAN PKWY SW
# 3  193651019.0  12/31/2019       1300         969 MARIETTA ST NW
# 4  193651039.0  12/31/2019       1300        3070 BOLLING WAY NE
#
#            UC2_Literal ibr_code            neighborhood       lat      long
# 0  LARCENY-NON VEHICLE     2308                Edgewood  33.76053 -84.34220
# 1  LARCENY-NON VEHICLE     2302           Ormewood Park  33.74179 -84.34973
# 2  LARCENY-NON VEHICLE     2303            Hammond Park  33.68092 -84.40814
# 3  LARCENY-NON VEHICLE     2303  Marietta Street Artery  33.77828 -84.40910
# 4  LARCENY-NON VEHICLE     2303        Buckhead Village  33.83888 -84.37995

# %%
crime_09_20.tail()
# Out:
#         offense_id occur_date occur_time                     location  \
# 21901  200011298.0   1/1/2020      14:45  2630 MARTIN L KING JR DR SW
# 21902  200011823.0   1/1/2020      20:00          540 HUMPHRIES ST SW
# 21903  200020105.0   1/1/2020      21:45           1174 EUCLID AVE NE
# 21904  200020704.0   1/1/2020      20:00     383 RALPH MCGILL BLVD NE
# 21905  201511120.0   1/1/2020      13:00        144 PONCE DE LEON AVE
#
#       UC2_Literal ibr_code     neighborhood       lat      long
# 21901  AUTO THEFT      NaN  Harland Terrace  33.75377 -84.47405
# 21902  AUTO THEFT      NaN   Mechanicsville  33.73990 -84.40488
# 21903  AUTO THEFT      NaN       Inman Park  33.76553 -84.34934
# 21904  AUTO THEFT      NaN  Old Fourth Ward  33.76391 -84.37489
# 21905  AUTO THEFT      NaN          Midtown  33.77255 -84.38249

# %%
crime_09_20['occur_date'].unique()
# Out:
# array(['12/31/2019', '12/30/2019', '12/29/2019', ..., '10/3/2020',
#        '10/2/2020', '10/1/2020'], dtype=object)

# %%
crime_09_20['UC2_Literal'].unique()
# Out:
# array(['LARCENY-NON VEHICLE', 'ROBBERY-PEDESTRIAN', 'HOMICIDE',
#        'AUTO THEFT', 'BURGLARY-NONRES', 'LARCENY-FROM VEHICLE',
#        'AGG ASSAULT', 'BURGLARY-RESIDENCE', 'ROBBERY-RESIDENCE',
#        'ROBBERY-COMMERCIAL', 'MANSLAUGHTER', 'ROBBERY', 'BURGLARY'],
#       dtype=object)

# %%
crime_09_20.to_csv("crime_09_20.csv",index=False, header=True)
