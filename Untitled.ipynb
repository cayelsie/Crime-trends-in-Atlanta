# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
crimerecord_2021="Resources/COBRA-2021.CSV"
crimerecord_202011="Resources/COBRA-2020.CSV"
crimerecord_2009_2019="Resources/COBRA-2009-2019.csv"
crimerecord_202009="Resources/COBRA-2020-old.CSV"

# %%
crimerecord_2021_df=pd.read_csv(crimerecord_2021,encoding="utf-8")
crimerecord_202009_df=pd.read_csv(crimerecord_202009,encoding="utf-8")
crimerecord_202011_df=pd.read_csv(crimerecord_202011,encoding="utf-8")
crimerecord_2009_2019_df=pd.read_csv(crimerecord_2009_2019,encoding="utf-8")

# %%
crimerecord_2009_2019_df.head()
# Out:
#    Report Number Report Date  Occur Date Occur Time Possible Date  \
# 0       90010930  2009-01-01  2009-01-01       1145    2009-01-01
# 1       90011083  2009-01-01  2009-01-01       1330    2009-01-01
# 2       90011208  2009-01-01  2009-01-01       1500    2009-01-01
# 3       90011218  2009-01-01  2009-01-01       1450    2009-01-01
# 4       90011289  2009-01-01  2009-01-01       1600    2009-01-01
#
#    Possible Time   Beat Apartment Office Prefix Apartment Number  \
# 0         1148.0  411.0                     NaN              NaN
# 1         1330.0  511.0                     NaN              NaN
# 2         1520.0  407.0                     NaN              NaN
# 3         1510.0  210.0                     NaN              NaN
# 4         1700.0  411.0                     NaN              NaN
#
#                       Location Shift Occurence Location Type  \
# 0         2841 GREENBRIAR PKWY       Day Watch             8
# ...

# %%
crimerecordxyz = pd.to_datetime(crimerecord_2009_2019_df['Occur Date'],format='%Y-%m-%d', errors='ignore')

# %%
crimerecordxyz
# Out:
# 0        2009-01-01
# 1        2009-01-01
# 2        2009-01-01
# 3        2009-01-01
# 4        2009-01-01
#             ...
# 342909   2019-12-31
# 342910   2019-12-31
# 342911   2019-12-31
# 342912   2019-12-31
# 342913   2019-12-31
# Name: Occur Date, Length: 342914, dtype: datetime64[ns]

# %%
crimerecord_abc = pd.to_datetime(crimerecord_2021_df['occur_date'],format='%m/%d/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-59-3f01fbe0d84a> in <module>
# ----> 1 crimerecord_abc = pd.to_datetime(crimerecord_2021_df['occur_date'],format='%m/%d/%Y')
#
# ...

# %%
# possible steps to rectify:
# lambda function
# filtering based on digits in year
# loop through the rows and columns

# %%
crimerecord_abc
# Out:
# 0        7/8/2020
# 1       6/13/2020
# 2       1/20/2021
# 3       10/5/2020
# 4       11/5/2020
#           ...
# 9299    1/27/2021
# 9300    1/28/2021
# 9301    1/28/2021
# 9302    1/28/2021
# 9303    1/20/2021
# Name: occur_date, Length: 9304, dtype: object

# %%
crimerecord_2021_df.columns

# %%
crimerecord_2021_df.head()

# %%
crimerecord_202009_df.columns

# %%
crimerecord_202009_df.head()

# %%
crimerecord_202011_df.columns

# %%
crimerecord_202011_df.head()

# %%
crimerecord_2009_2019_df.columns

# %%
crimerecord_202009_clean=crimerecord_202009_df[['offense_id',  'occur_date', 'occur_time',  'location',
    'UC2_Literal','ibr_code', 'neighborhood', 'long', 'lat']]
crimerecord_202009_clean.head()
# Out:
#    offense_id occur_date occur_time                location UC2_Literal  \
# 0   200021209   1/2/2020      15:21          12 BROAD ST SW    HOMICIDE
# 1   200061707   1/6/2020       0:00       785 PEYTON AVE NW    HOMICIDE
# 2   200100013   1/9/2020      23:45       1977 JONES AVE NW    HOMICIDE
# 3   200151818  1/15/2020      17:15  549 JOSEPH LOWERY BLVD    HOMICIDE
# 4   200180440  1/18/2020       3:31          28 IRBY AVE NW    HOMICIDE
#
#    ibr_code       neighborhood      long       lat
# 0       NaN           Downtown -84.39189  33.75352
# 1       NaN        Center Hill -84.46770  33.77655
# 2       NaN     West Highlands -84.45208  33.78738
# 3       NaN           West End -84.41782  33.74001
# 4       NaN  South Tuxedo Park -84.38018  33.84102

# %%
crimerecord_2009_2019_clean=crimerecord_2009_2019_df[['Report Number', 'Occur Date', 'Occur Time', 'Location', 
       'UCR Literal','IBR Code','Neighborhood', 'Latitude','Longitude']]
crimerecord_2009_2019_clean.head()
# Out:
#    Report Number  Occur Date Occur Time                     Location  \
# 0       90010930  2009-01-01       1145         2841 GREENBRIAR PKWY
# 1       90011083  2009-01-01       1330               12 BROAD ST SW
# 2       90011208  2009-01-01       1500  3500 MARTIN L KING JR DR SW
# 3       90011218  2009-01-01       1450         3393 PEACHTREE RD NE
# 4       90011289  2009-01-01       1600      2841 GREENBRIAR PKWY SW
#
#            UCR Literal IBR Code Neighborhood  Latitude  Longitude
# 0  LARCENY-NON VEHICLE     2303   Greenbriar  33.68845  -84.49328
# 1  LARCENY-NON VEHICLE     2303     Downtown  33.75320  -84.39201
# 2  LARCENY-NON VEHICLE     2303   Adamsville  33.75735  -84.50282
# 3  LARCENY-NON VEHICLE     2303        Lenox  33.84676  -84.36212
# 4  LARCENY-NON VEHICLE     2303   Greenbriar  33.68677  -84.49773

# %%
crimerecord_202011_clean=crimerecord_202011_df[['offense_id',  'occur_date', 'occur_time', 'location', 
        'UC2_Literal','ibr_code','neighborhood', 'lat', 'long']]
crimerecord_202011_clean.head()
# Out:
#    offense_id  occur_date occur_time              location  \
# 0   203341346  11/29/2020      19:21  3050 M.L.K. JR DR SW
# 1   203631200  12/28/2020      17:21        1186 IRA ST SW
# 2   203631285  12/24/2020      14:00   501 BOULEVARD PL NE
# 3   203651634  12/30/2020      20:15   3101 PIEDMONT RD NE
# 4   203660108  12/31/2020       1:15     1974 SYLVAN RD SW
#
#             UC2_Literal ibr_code     neighborhood        lat       long
# 0           AGG ASSAULT      13A  Harland Terrace  33.751060 -84.486163
# 1   LARCENY-NON VEHICLE      23H       Pittsburgh  33.722696 -84.399763
# 2   LARCENY-NON VEHICLE      23H  Old Fourth Ward  33.769680 -84.370736
# 3  LARCENY-FROM VEHICLE      23F   Peachtree Park  33.840653 -84.369361
# 4           AGG ASSAULT      13A     Sylvan Hills  33.700432 -84.418128

# %%
crimerecord_2021_clean=crimerecord_2021_df[['offense_id', 'occur_date', 'occur_time', 'location', 'ibr_code', 'UC2_Literal',
       'neighborhood', 'lat', 'long']]

crimerecord_2021_clean.head()
# Out:
#    offense_id occur_date occur_time               location ibr_code  \
# 0   200006928   7/8/2020      10:00   1888 HOLLYWOOD RD NW      240
# 1   200016928  6/13/2020      13:00    595 PIEDMONT AVE NE      23C
# 2   200201253  1/20/2021      04:00  2479 ABNER TERRACE NW      23G
# 3   201791305  10/5/2020      16:00      2143 PEACHTREE RD      23H
# 4   202101654  11/5/2020      19:37       177 MOURY AVE SE      13A
#
#             UC2_Literal            neighborhood        lat       long
# 0            AUTO THEFT               Riverside  33.807140 -84.471539
# 1   LARCENY-NON VEHICLE         Old Fourth Ward  33.770357 -84.381158
# 2  LARCENY-FROM VEHICLE         Scotts Crossing  33.800999 -84.466556
# 3   LARCENY-NON VEHICLE                     NaN  33.812773 -84.391538
# 4           AGG ASSAULT  The Villages at Carver  33.713540 -84.390301

# %%
crime_2020 = crimerecord_202009_clean.append(crimerecord_202011_clean)
crime_2020
# Out:
#       offense_id occur_date occur_time                  location  \
# 0      200021209   1/2/2020      15:21            12 BROAD ST SW
# 1      200061707   1/6/2020       0:00         785 PEYTON AVE NW
# 2      200100013   1/9/2020      23:45         1977 JONES AVE NW
# 3      200151818  1/15/2020      17:15    549 JOSEPH LOWERY BLVD
# 4      200180440  1/18/2020       3:31            28 IRBY AVE NW
# ...          ...        ...        ...                       ...
# 7244   202740875  9/30/2020      12:27          238 PETERS ST SW
# 7245   202740912  9/30/2020      14:00          615 BOULEVARD SE
# 7246   202660701  9/16/2020       7:00  1395 METROPOLITAN AVE SE
# 7247   202680663  9/19/2020      12:00             848 FOX ST NW
# 7248   202741780  9/30/2020      16:48            17 BAKER ST NW
#
#                UC2_Literal ibr_code       neighborhood       long        lat
# 0                 HOMICIDE      NaN           Downtown -84.391890  33.753520
# ...

# %%
crime_2020_2021=crime_2020.append(crimerecord_2021_clean)
crime_2020_2021
# Out:
#       offense_id occur_date occur_time                location  \
# 0      200021209   1/2/2020      15:21          12 BROAD ST SW
# 1      200061707   1/6/2020       0:00       785 PEYTON AVE NW
# 2      200100013   1/9/2020      23:45       1977 JONES AVE NW
# 3      200151818  1/15/2020      17:15  549 JOSEPH LOWERY BLVD
# 4      200180440  1/18/2020       3:31          28 IRBY AVE NW
# ...          ...        ...        ...                     ...
# 9299   210280231  1/27/2021      21:15  2343 CAMPBELLTON RD SW
# 9300   210280239  1/28/2021      02:37     485 LINDBERGH PL NE
# 9301   210280257  1/28/2021      03:26              3186 US-78
# 9302   210280267  1/28/2021      02:23        323 SPRING ST NW
# 9303   210919771  1/20/2021      09:49      285 WILLIAMS ST NW
#
#                UC2_Literal ibr_code       neighborhood       long        lat
# 0                 HOMICIDE      NaN           Downtown -84.391890  33.753520
# ...

# %%
crime_09_19=crimerecord_2009_2019_clean.rename(columns={'Report Number':"offense_id", "Occur Date":"occur_date", "Occur Time":"occur_time", 
                                                        'Location':'location',  'UCR Literal':'UC2_Literal','IBR Code':'ibr_code','Neighborhood':'neighborhood', 'Latitude':'lat','Longitude':'long'})

crime_09_19
# Out:
#         offense_id  occur_date occur_time                     location  \
# 0         90010930  2009-01-01       1145         2841 GREENBRIAR PKWY
# 1         90011083  2009-01-01       1330               12 BROAD ST SW
# 2         90011208  2009-01-01       1500  3500 MARTIN L KING JR DR SW
# 3         90011218  2009-01-01       1450         3393 PEACHTREE RD NE
# 4         90011289  2009-01-01       1600      2841 GREENBRIAR PKWY SW
# ...            ...         ...        ...                          ...
# 342909   193652089  2019-12-31       2030            1385 SHARON ST NW
# 342910   193650336  2019-12-31        432              262 PHARR RD NE
# 342911   193650603  2019-12-31        920           689 CASCADE AVE SW
# 342912   193651760  2019-12-31       1853           763 CASCADE AVE SW
# 342913   193652591  2019-12-31       2045             237 PEYTON PL SW
#
#                 UC2_Literal ibr_code         neighborhood       lat      long
# ...

# %%
crime_09_21=crime_09_19.append(crime_2020_2021)
crime_09_21
# Out:
#       offense_id  occur_date occur_time                     location  \
# 0       90010930  2009-01-01       1145         2841 GREENBRIAR PKWY
# 1       90011083  2009-01-01       1330               12 BROAD ST SW
# 2       90011208  2009-01-01       1500  3500 MARTIN L KING JR DR SW
# 3       90011218  2009-01-01       1450         3393 PEACHTREE RD NE
# 4       90011289  2009-01-01       1600      2841 GREENBRIAR PKWY SW
# ...          ...         ...        ...                          ...
# 9299   210280231   1/27/2021      21:15       2343 CAMPBELLTON RD SW
# 9300   210280239   1/28/2021      02:37          485 LINDBERGH PL NE
# 9301   210280257   1/28/2021      03:26                   3186 US-78
# 9302   210280267   1/28/2021      02:23             323 SPRING ST NW
# 9303   210919771   1/20/2021      09:49           285 WILLIAMS ST NW
#
#                UC2_Literal ibr_code       neighborhood        lat       long
# ...

# %%
crime_09_21.count()
# Out:
# offense_id      374298
# occur_date      374283
# occur_time      374283
# location        374296
# UC2_Literal     374298
# ibr_code        359297
# neighborhood    360598
# lat             374298
# long            374298
# dtype: int64

# %%
crime_09_21=crime_09_21.dropna(how='any')

# %%
crime_09_21.count()
# Out:
# offense_id      346272
# occur_date      346272
# occur_time      346272
# location        346272
# UC2_Literal     346272
# ibr_code        346272
# neighborhood    346272
# lat             346272
# long            346272
# timestamp       346272
# dtype: int64

# %%
crime_09_21.dtypes
# Out:
# offense_id        int64
# occur_date       object
# occur_time       object
# location         object
# UC2_Literal      object
# ibr_code         object
# neighborhood     object
# lat             float64
# long            float64
# timestamp        object
# dtype: object

# %%
crime_09_21.head()
# Out:
#    offense_id  occur_date occur_time                     location  \
# 0    90010930  2009-01-01       1145         2841 GREENBRIAR PKWY
# 1    90011083  2009-01-01       1330               12 BROAD ST SW
# 2    90011208  2009-01-01       1500  3500 MARTIN L KING JR DR SW
# 3    90011218  2009-01-01       1450         3393 PEACHTREE RD NE
# 4    90011289  2009-01-01       1600      2841 GREENBRIAR PKWY SW
#
#            UC2_Literal ibr_code neighborhood       lat      long   timestamp
# 0  LARCENY-NON VEHICLE     2303   Greenbriar  33.68845 -84.49328  2009-01-01
# 1  LARCENY-NON VEHICLE     2303     Downtown  33.75320 -84.39201  2009-01-01
# 2  LARCENY-NON VEHICLE     2303   Adamsville  33.75735 -84.50282  2009-01-01
# 3  LARCENY-NON VEHICLE     2303        Lenox  33.84676 -84.36212  2009-01-01
# 4  LARCENY-NON VEHICLE     2303   Greenbriar  33.68677 -84.49773  2009-01-01

# %%
crime_09_21.tail()
# Out:
#       offense_id occur_date occur_time                location  \
# 9299   210280231  1/27/2021      21:15  2343 CAMPBELLTON RD SW
# 9300   210280239  1/28/2021      02:37     485 LINDBERGH PL NE
# 9301   210280257  1/28/2021      03:26              3186 US-78
# 9302   210280267  1/28/2021      02:23        323 SPRING ST NW
# 9303   210919771  1/20/2021      09:49      285 WILLIAMS ST NW
#
#                UC2_Literal ibr_code       neighborhood        lat       long  \
# 9299  LARCENY-FROM VEHICLE      23F          Southwest  33.704558 -84.465379
# 9300           AGG ASSAULT      13A  Lindbergh/Morosgo  33.820101 -84.371098
# 9301  LARCENY-FROM VEHICLE      23F    Collier Heights  33.785756 -84.491515
# 9302  LARCENY-FROM VEHICLE      23F           Downtown  33.763580 -84.388717
# 9303  LARCENY-FROM VEHICLE      23F           Downtown  33.763189 -84.390543
#
#       timestamp
# 9299  1/27/2021
# 9300  1/28/2021
# 9301  1/28/2021
# 9302  1/28/2021
# 9303  1/20/2021

# %%
crime_09_21['occur_date'].unique()
# Out:
# array(['2009-01-01', '2008-12-31', '2008-12-29', ..., '1/26/2021',
#        '1/27/2021', '1/28/2021'], dtype=object)

# %%
crime_09_21['timestamp'] = pd.to_datetime(crime_09_21['occur_date'],format='%Y%m%d', errors='ignore')
crime_09_21['timestamp']
# Out:
# 0       2009-01-01
# 1       2009-01-01
# 2       2009-01-01
# 3       2009-01-01
# 4       2009-01-01
#            ...
# 9299     1/27/2021
# 9300     1/28/2021
# 9301     1/28/2021
# 9302     1/28/2021
# 9303     1/20/2021
# Name: timestamp, Length: 374298, dtype: object

# %%
timestamp=crime_09_21.loc[crime_09_21['timestamp']>='2020-01-01',:]
timestamp
# Out:
#       offense_id occur_date occur_time                            location  \
# 12     200610909   3/1/2020      11:49                 725 GARIBALDI ST SW
# 13     200681491   3/8/2020      18:39  3393 PEACHTREE RD NE @LENOX SQUARE
# 14     200731916  3/13/2020      18:51                 836 GLENDALE TER NE
# 15     200741761  3/14/2020      19:00                  273 FLETCHER ST SW
# 16     200761557  3/16/2020      19:00                  211 THORNTON ST SW
# ...          ...        ...        ...                                 ...
# 7100   203640551  5/13/2019      13:00                   232 FORSYTH ST SW
# 8188   210130850  9/22/2020      00:00                3275 PEACHTREE RD NE
# 8744   210210677  4/21/2020      12:00                 202 COURTLAND ST NE
# 8760   210211353  7/15/2020      09:00                 202 COURTLAND ST NE
# 9183   210260826   9/9/2020      12:00                   3230 PEACHTREE RD
#
# ...

# %%
crime_09_21['occur_year'] = pd.DatetimeIndex(crime_09_21['timestamp']).year
crime_09_21.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2053         try:
# -> 2054             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2055             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-33-60ae6b473571> in <module>
# ----> 1 crime_09_21['occur_year'] = pd.DatetimeIndex(crime_09_21['timestamp']).year
#       2 crime_09_21.head()
#
# ...

# %%
crime_09_21['UC2_Literal'].unique()
# Out:
# array(['LARCENY-NON VEHICLE', 'LARCENY-FROM VEHICLE',
#        'ROBBERY-PEDESTRIAN', 'ROBBERY-RESIDENCE', 'AUTO THEFT',
#        'AGG ASSAULT', 'BURGLARY-RESIDENCE', 'BURGLARY-NONRES',
#        'ROBBERY-COMMERCIAL', 'HOMICIDE', 'MANSLAUGHTER', 'ROBBERY',
#        'BURGLARY'], dtype=object)

# %%
crime_09_21.to_csv("crime_09_21.csv",index=False, header=True)
