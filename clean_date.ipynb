# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
crime_09_20="crime_09_20.csv"
crimer_2020_df=pd.read_csv(crime_09_20,encoding="utf-8")
# Out:
# C:\Users\gsun\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
crime_newtime = pd.to_datetime(crimer_2021_df['occur_date'],format='%Y-%m-%d', errors='ignore')
crime_newtime
# Out:
# 0         6/17/2009
# 1         2/24/2010
# 2         1/25/2010
# 3          1/1/2009
# 4          1/1/2009
#             ...
# 345876    1/27/2021
# 345877    1/28/2021
# 345878    1/28/2021
# 345879    1/28/2021
# 345880    1/20/2021
# Name: occur_date, Length: 345880, dtype: object

# %%
crimer_2020_df.head()
# Out:
#     offense_id  occur_date occur_time                   location  \
# 0  193651657.0  12/31/2019       1458       1388 LA FRANCE ST NE
# 1  193651031.0  12/31/2019       1300        443 MORELAND AVE SE
# 2  193650870.0  12/31/2019       1200  2711 METROPOLITAN PKWY SW
# 3  193651019.0  12/31/2019       1300         969 MARIETTA ST NW
# 4  193651039.0  12/31/2019       1300        3070 BOLLING WAY NE
#
#            UC2_Literal ibr_code            neighborhood       lat      long
# 0  LARCENY-NON VEHICLE     2308                Edgewood  33.76053 -84.34220
# 1  LARCENY-NON VEHICLE     2302           Ormewood Park  33.74179 -84.34973
# 2  LARCENY-NON VEHICLE     2303            Hammond Park  33.68092 -84.40814
# 3  LARCENY-NON VEHICLE     2303  Marietta Street Artery  33.77828 -84.40910
# 4  LARCENY-NON VEHICLE     2303        Buckhead Village  33.83888 -84.37995

# %%
crimer_2020_df.tail()
# Out:
#          offense_id occur_date occur_time                     location  \
# 364417  200011298.0   1/1/2020      14:45  2630 MARTIN L KING JR DR SW
# 364418  200011823.0   1/1/2020      20:00          540 HUMPHRIES ST SW
# 364419  200020105.0   1/1/2020      21:45           1174 EUCLID AVE NE
# 364420  200020704.0   1/1/2020      20:00     383 RALPH MCGILL BLVD NE
# 364421  201511120.0   1/1/2020      13:00        144 PONCE DE LEON AVE
#
#        UC2_Literal ibr_code     neighborhood       lat      long
# 364417  AUTO THEFT      NaN  Harland Terrace  33.75377 -84.47405
# 364418  AUTO THEFT      NaN   Mechanicsville  33.73990 -84.40488
# 364419  AUTO THEFT      NaN       Inman Park  33.76553 -84.34934
# 364420  AUTO THEFT      NaN  Old Fourth Ward  33.76391 -84.37489
# 364421  AUTO THEFT      NaN          Midtown  33.77255 -84.38249

# %%
crimer_2020_df=crimer_2020_df.dropna(how='all')

# %%
crimer_2020_df.tail()
# Out:
#          offense_id occur_date occur_time                     location  \
# 364417  200011298.0   1/1/2020      14:45  2630 MARTIN L KING JR DR SW
# 364418  200011823.0   1/1/2020      20:00          540 HUMPHRIES ST SW
# 364419  200020105.0   1/1/2020      21:45           1174 EUCLID AVE NE
# 364420  200020704.0   1/1/2020      20:00     383 RALPH MCGILL BLVD NE
# 364421  201511120.0   1/1/2020      13:00        144 PONCE DE LEON AVE
#
#        UC2_Literal ibr_code     neighborhood       lat      long
# 364417  AUTO THEFT      NaN  Harland Terrace  33.75377 -84.47405
# 364418  AUTO THEFT      NaN   Mechanicsville  33.73990 -84.40488
# 364419  AUTO THEFT      NaN       Inman Park  33.76553 -84.34934
# 364420  AUTO THEFT      NaN  Old Fourth Ward  33.76391 -84.37489
# 364421  AUTO THEFT      NaN          Midtown  33.77255 -84.38249

# %%
crimer_2020_df['occur_year'] = pd.DatetimeIndex(crimer_2020_df['occur_date']).year
crimer_2020_df.head()
# Out:
#     offense_id  occur_date occur_time                   location  \
# 0  193651657.0  12/31/2019       1458       1388 LA FRANCE ST NE
# 1  193651031.0  12/31/2019       1300        443 MORELAND AVE SE
# 2  193650870.0  12/31/2019       1200  2711 METROPOLITAN PKWY SW
# 3  193651019.0  12/31/2019       1300         969 MARIETTA ST NW
# 4  193651039.0  12/31/2019       1300        3070 BOLLING WAY NE
#
#            UC2_Literal ibr_code            neighborhood       lat      long  \
# 0  LARCENY-NON VEHICLE     2308                Edgewood  33.76053 -84.34220
# 1  LARCENY-NON VEHICLE     2302           Ormewood Park  33.74179 -84.34973
# 2  LARCENY-NON VEHICLE     2303            Hammond Park  33.68092 -84.40814
# 3  LARCENY-NON VEHICLE     2303  Marietta Street Artery  33.77828 -84.40910
# 4  LARCENY-NON VEHICLE     2303        Buckhead Village  33.83888 -84.37995
#
#    occur_year
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019

# %%
crimer_2020_df['occur_month'] = pd.DatetimeIndex(crimer_2020_df['occur_date']).month
crimer_2020_df.head()
# Out:
#     offense_id  occur_date occur_time                   location  \
# 0  193651657.0  12/31/2019       1458       1388 LA FRANCE ST NE
# 1  193651031.0  12/31/2019       1300        443 MORELAND AVE SE
# 2  193650870.0  12/31/2019       1200  2711 METROPOLITAN PKWY SW
# 3  193651019.0  12/31/2019       1300         969 MARIETTA ST NW
# 4  193651039.0  12/31/2019       1300        3070 BOLLING WAY NE
#
#            UC2_Literal ibr_code            neighborhood       lat      long  \
# 0  LARCENY-NON VEHICLE     2308                Edgewood  33.76053 -84.34220
# 1  LARCENY-NON VEHICLE     2302           Ormewood Park  33.74179 -84.34973
# 2  LARCENY-NON VEHICLE     2303            Hammond Park  33.68092 -84.40814
# 3  LARCENY-NON VEHICLE     2303  Marietta Street Artery  33.77828 -84.40910
# 4  LARCENY-NON VEHICLE     2303        Buckhead Village  33.83888 -84.37995
#
#    occur_year  occur_month
# 0        2019           12
# 1        2019           12
# 2        2019           12
# ...

# %%
crimer_2020_df.to_csv("crime_09_20_clean.csv",index=False, header=True)

# %%
crime_18_20=crimer_2020_df.loc[(crimer_2020_df['occur_year']==2021)|(crimer_2020_df['occur_year']==2020)|(crimer_2020_df['occur_year']==2019)|(crimer_2020_df['occur_year']==2018),:]
crime_18_20.head()
# Out:
#     offense_id  occur_date occur_time                   location  \
# 0  193651657.0  12/31/2019       1458       1388 LA FRANCE ST NE
# 1  193651031.0  12/31/2019       1300        443 MORELAND AVE SE
# 2  193650870.0  12/31/2019       1200  2711 METROPOLITAN PKWY SW
# 3  193651019.0  12/31/2019       1300         969 MARIETTA ST NW
# 4  193651039.0  12/31/2019       1300        3070 BOLLING WAY NE
#
#            UC2_Literal ibr_code            neighborhood       lat      long  \
# 0  LARCENY-NON VEHICLE     2308                Edgewood  33.76053 -84.34220
# 1  LARCENY-NON VEHICLE     2302           Ormewood Park  33.74179 -84.34973
# 2  LARCENY-NON VEHICLE     2303            Hammond Park  33.68092 -84.40814
# 3  LARCENY-NON VEHICLE     2303  Marietta Street Artery  33.77828 -84.40910
# 4  LARCENY-NON VEHICLE     2303        Buckhead Village  33.83888 -84.37995
#
#    occur_year  occur_month
# 0        2019           12
# 1        2019           12
# 2        2019           12
# ...

# %%
crime_march=crimer_2020_df.loc[(crimer_2020_df['occur_month']==3)]
crime_march
# Out:
#          offense_id occur_date occur_time                       location  \
# 19586   190900496.0  3/31/2019        549               180 WALKER ST SW
# 19587   190900596.0  3/31/2019        640         2191 CAMPBELLTON RD SW
# 19588   190901678.0  3/31/2019        800        2800 FORREST PARK RD SE
# 19589   190901468.0  3/31/2019       1811         3909 CAMPBELLTON RD SW
# 19590   190900075.0  3/31/2019         15      3057 PHARR COURT NORTH NW
# ...             ...        ...        ...                            ...
# 360457  200610935.0   3/1/2020      12:00      1176 CHATTAHOOCHEE AVE NW
# 360458  200611745.0   3/1/2020      20:40             633 FORMWALT ST SW
# 360459  200618065.0   3/1/2020      15:30  4300 GLOBAL GATEWAY CONNECTOR
# 360460  200620238.0   3/1/2020      23:56                345 PHARR RD NE
# 360461  200621247.0   3/1/2020      17:00           915 GREENWOOD AVE NE
#
#             UC2_Literal ibr_code            neighborhood       lat      long  \
# ...

# %%
grouped_neighbor=crime_18_20.groupby(['neighborhood'])
print(grouped_neighbor)
grouped_count=grouped_neighbor.count()

# %%
crime_18_21['neighborhood'].unique()
# Out:
# array(['Grant Park', 'Sylvan Hills', 'Adamsville', 'West End', 'Downtown',
#        'Fairburn Mays', 'Center Hill', 'Adair Park',
#        'Atlanta University Center', 'Morningside/Lenox Park', 'Perkerson',
#        'Midtown', 'Ashview Heights', 'Blandtown', 'Rockdale',
#        'Wildwood (NPU-C)', 'Berkeley Park', 'Pittsburgh', 'Westview',
#        'Underwood Hills', 'Lakewood Heights', 'Lindbergh/Morosgo',
#        'Lenox', 'Princeton Lakes', 'West Lake', 'Old Fourth Ward',
#        'East Atlanta', 'Cascade Avenue/Road', 'Buckhead Forest',
#        'Hammond Park', 'Riverside', 'Glenrose Heights',
#        'Atlantic Station', 'Oakland City', 'Collier Heights', 'Kingswood',
#        'Wildwood (NPU-H)', 'Marietta Street Artery', 'Home Park',
#        'Monroe Heights', 'Mozley Park', 'Leila Valley', 'West Highlands',
#        'North Buckhead', 'Poncey-Highland', 'Virginia Highland',
#        'Lindridge/Martin Manor', 'Candler Park', 'Druid Hills',
# ...

# %%
grouped_count_sort=grouped_count.sort_values(['offense_id'],ascending=False)
grouped_count_sort.head(20)
# Out:
#                         offense_id  occur_date  occur_time  location  \
# neighborhood
# Downtown                      5864        5864        5864      5864
# Midtown                       4591        4591        4591      4591
# Old Fourth Ward               1730        1730        1730      1730
# Lindbergh/Morosgo             1658        1658        1658      1658
# West End                      1383        1383        1383      1383
# Home Park                     1303        1303        1303      1303
# North Buckhead                1303        1303        1303      1303
# Vine City                     1122        1122        1122      1122
# Lenox                         1092        1092        1092      1092
# Inman Park                    1058        1058        1058      1058
# Berkeley Park                 1016        1016        1016      1016
# Castleberry Hill               970         970         970       970
# ...
